# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# **The original dataset can be found on Kaggle**
#
# **URL = https://www.kaggle.com/datasets/trolukovich/steam-games-complete-dataset?resource=download**
#
# **It is licensed with "CC0: Public Domain" which allows me to use the dataset**

# %% [markdown]
# # 1. Loading the dataset
# **Starting with importing libraries and reading the dataset.**

# %%
import re
import random
import warnings

import pandas as pd

from collections import Counter

warnings.filterwarnings("ignore")

# %%
dataframe = pd.read_csv("Datasets/steam_games.csv")
dataframe.shape
# Out:
# (40833, 20)

# %%
dataframe.head()
# Out:
#                                                  url types
# 0    https://store.steampowered.com/app/379720/DOOM/   app  \
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name
# 0                           DOOM  \
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet
# 0  Now includes all three premium DLC packs (Unto...  \
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews
# 0  Very Positive,(554),- 89% of the 554 user revi...  \
# 1  Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  Mixed,(166),- 54% of the 166 user reviews in t...
# 3  Mixed,(932),- 57% of the 932 user reviews in t...
# 4  Mixed,(287),- 54% of the 287 user reviews in t...
#
#                                          all_reviews  release_date
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016  \
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
#
#              developer                                publisher
# 0          id Software    Bethesda Softworks,Bethesda Softworks  \
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                  CCP                                  CCP,CCP
#
#                                         popular_tags
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  \
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                         game_details
# 0  Single-player,Multi-player,Co-op,Steam Achieve...  \
# 1             Multi-player,Online Multi-Player,Stats
# 2  Single-player,Multi-player,Online Multi-Player...
# 3  Multi-player,Online Multi-Player,Steam Worksho...
# 4  Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                            languages  achievements
# 0  English,French,Italian,German,Spanish - Spain,...          54.0  \
# 1  English,Korean,Simplified Chinese,French,Germa...          37.0
# 2                      English,French,German,Russian         128.0
# 3  English,French,Italian,German,Spanish - Spain,...           NaN
# 4                      English,German,Russian,French           NaN
#
#                                                genre
# 0                                             Action  \
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                     game_description
# 0   About This Game Developed by id software, the...  \
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
#
#                                       mature_content
# 0                                                NaN  \
# 1   Mature Content Description  The developers de...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 minimum_requirements
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...  \
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
# 3  Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4  Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
#
#                             recommended_requirements original_price
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...         $19.99  \
# 1  Recommended:,Requires a 64-bit processor and o...         $29.99
# 2  Recommended:,Requires a 64-bit processor and o...         $39.99
# 3  Recommended:,OS:,Windows 10 64-bit,Processor:,...         $44.99
# 4  Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
#
#   discount_price
# 0         $14.99
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# # 2. Cleaning the dataset
# **I get the idea how data looks now. Next step is to check for missing values in dataset and drop rows with missing one.**

# %% [markdown]
# **1. Column "name"**

# %%
dataframe.loc[dataframe["name"].isna()].index
# Out:
# Index([  704,  4847,  6381,  7869,  9615,  9616,  9956, 12146, 12879, 23099,
#        28380, 31321, 34989, 34991, 35169, 39575],
#       dtype='int64')

# %%
dataframe = dataframe.drop(dataframe.loc[dataframe["name"].isna()].index)
dataframe.loc[dataframe["name"].isna()].index
# Out:
# Index([], dtype='int64')

# %%
dataframe.shape
# Out:
# (40817, 20)

# %% [markdown]
# **I have 16 rows less now.**

# %% [markdown]
# **2. Irrelevant columns**

# %% [markdown]
# **Next step is to drop columns which provide us with no usable data. Taking into account the goal - predict the popularity of the new game. Upon release most of this data is absent.**

# %%
dataframe_clean = dataframe.drop(["url", "types", "desc_snippet", "recent_reviews", "achievements",
                                      "game_description", "mature_content", "minimum_requirements",
                                     "recommended_requirements", "original_price", "discount_price"], axis=1)
dataframe_clean.head()
# Out:
#                             name
# 0                           DOOM  \
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                          all_reviews  release_date
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016  \
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
#
#              developer                                publisher
# 0          id Software    Bethesda Softworks,Bethesda Softworks  \
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                  CCP                                  CCP,CCP
#
#                                         popular_tags
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  \
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                         game_details
# 0  Single-player,Multi-player,Co-op,Steam Achieve...  \
# 1             Multi-player,Online Multi-Player,Stats
# 2  Single-player,Multi-player,Online Multi-Player...
# 3  Multi-player,Online Multi-Player,Steam Worksho...
# 4  Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                            languages
# 0  English,French,Italian,German,Spanish - Spain,...  \
# 1  English,Korean,Simplified Chinese,French,Germa...
# 2                      English,French,German,Russian
# 3  English,French,Italian,German,Spanish - Spain,...
# 4                      English,German,Russian,French
#
#                                                genre
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...

# %% [markdown]
# **4. Column "release_date"**

# %%
dataframe_clean.loc[dataframe_clean["release_date"].isna()].index
# Out:
# Index([    5,    15,    25,    39,    44,    57,    63,    66,    68,    74,
#        ...
#        40239, 40281, 40315, 40326, 40339, 40401, 40454, 40536, 40651, 40701],
#       dtype='int64', length=3164)

# %%
dataframe_clean = dataframe_clean.drop(dataframe_clean.loc[dataframe_clean["release_date"].isna()].index)
dataframe_clean.loc[dataframe_clean["release_date"].isna()].index
# Out:
# Index([], dtype='int64')

# %%
dataframe_clean.shape
# Out:
# (37653, 9)

# %% [markdown]
# **132 less rows. Insignificant on the chunk of data left.**

# %% [markdown]
# **5. Column "developer"**

# %%
dataframe_clean.loc[dataframe_clean["developer"].isna()].index
# Out:
# Index([  146,  1101,  1854,  2517,  2712,  3471,  3989,  4722,  4854,  4933,
#        ...
#        39457, 39458, 39679, 39680, 39706, 40133, 40234, 40248, 40266, 40785],
#       dtype='int64', length=275)

# %%
dataframe_clean = dataframe_clean.drop(dataframe_clean.loc[dataframe_clean["developer"].isna()].index)
dataframe_clean.loc[dataframe_clean["developer"].isna()].index
# Out:
# Index([], dtype='int64')

# %%
dataframe_clean.shape
# Out:
# (37378, 9)

# %% [markdown]
# **155 less rows. Insignificant on the chunk of data left.**

# %% [markdown]
# **6. Column "publisher"**

# %%
dataframe_clean.loc[dataframe_clean["publisher"].isna()].index
# Out:
# Index([   45,  1061,  1899,  1979,  2422,  2574,  2645,  2711,  2854,  2941,
#        ...
#        40812, 40814, 40817, 40819, 40820, 40821, 40827, 40828, 40829, 40830],
#       dtype='int64', length=4726)

# %%
dataframe_clean = dataframe_clean.drop(dataframe_clean.loc[dataframe_clean["publisher"].isna()].index)
dataframe_clean.loc[dataframe_clean["publisher"].isna()].index
# Out:
# Index([], dtype='int64')

# %%
dataframe_clean.shape
# Out:
# (32652, 9)

# %% [markdown]
# **2096 less rows. Significant loss, but no way to fill the missing data.**

# %% [markdown]
# **7. Column "popular_tags"**

# %%
dataframe_clean.loc[dataframe_clean["popular_tags"].isna()].index
# Out:
# Index([ 1433,  6027, 10649, 10664, 11206, 11377, 11379, 11814, 11940, 11942,
#        12508, 12663, 13206, 13213, 13967, 14104, 14702, 14763, 15580, 15635,
#        15637, 15740, 16082, 16139, 16583, 17437, 18580, 19396, 19996, 20268,
#        21321, 21642, 22442, 23009, 23050, 23414, 23562, 24129, 25036, 27069,
#        27845, 28949, 31218, 31227, 31615, 31754, 32041, 32045, 32633, 32673,
#        34091, 34092, 34271, 34357, 34608, 34969, 35132, 35159, 35160, 35161,
#        35384, 35527, 36381, 37251, 37393, 37394, 38333, 38835, 40729],
#       dtype='int64')

# %%
dataframe_clean = dataframe_clean.drop(dataframe_clean.loc[dataframe_clean["popular_tags"].isna()].index)
dataframe_clean.loc[dataframe_clean["popular_tags"].isna()].index
# Out:
# Index([], dtype='int64')

# %%
dataframe_clean.shape
# Out:
# (32583, 9)

# %% [markdown]
# **47 less rows. Insignificant on the chunk of data left.**

# %% [markdown]
# **8. Column "game_details"**

# %%
dataframe_clean.loc[dataframe_clean["game_details"].isna()].index
# Out:
# Index([  478,   663,   727,   859,   949,  1007,  1052,  1114,  1153,  1305,
#        ...
#        36284, 36685, 36701, 36821, 36874, 37314, 37456, 37489, 39721, 40693],
#       dtype='int64', length=290)

# %%
dataframe_clean = dataframe_clean.drop(dataframe_clean.loc[dataframe_clean["game_details"].isna()].index)
dataframe_clean.loc[dataframe_clean["game_details"].isna()].index
# Out:
# Index([], dtype='int64')

# %%
dataframe_clean.shape
# Out:
# (32293, 9)

# %% [markdown]
# **273 less rows. Insignificant on the chunk of data left.**

# %% [markdown]
# **9. Column "languages"**

# %%
dataframe_clean.loc[dataframe_clean["languages"].isna()].index
# Out:
# Index([], dtype='int64')

# %% [markdown]
# **No missing data.**

# %% [markdown]
# **10. Column "genre"**

# %%
dataframe_clean.loc[dataframe_clean["genre"].isna()].index
# Out:
# Index([  211,   528,  1613,  2254,  2603,  3639,  4018,  5211,  6127,  6743,
#         6990,  7138,  7510,  7836,  8239,  8780, 10677, 11948, 12388, 12987,
#        13857, 14871, 14879, 14880, 14884, 15119, 16370, 18200, 18268, 19055,
#        21998, 22570, 23695, 23696, 24331, 24884, 26416, 27277, 27402, 29379,
#        30928, 39098],
#       dtype='int64')

# %%
dataframe_clean = dataframe_clean.drop(dataframe_clean.loc[dataframe_clean["genre"].isna()].index)
dataframe_clean.loc[dataframe_clean["genre"].isna()].index
# Out:
# Index([], dtype='int64')

# %%
dataframe_clean.shape
# Out:
# (32251, 9)

# %% [markdown]
# **38 less rows. Insignificant on the chunk of data left.**

# %% [markdown]
# # 2 Reshaping the dataset

# %% [markdown]
# **1. Creating the column "has_setting". It describes wether the game starts the setting or continue it.**

# %%
# function looks for numbers in range (2-10) in the column "name" and returns True if there is a number in a string
def check_for_setting(name):
    setting = re.findall(r"\d+", name)
    if setting:
        for i in setting:
            if 2 <= int(i) <= 10:
                return True
    return False

# %%
dataframe_clean["has_setting"] = dataframe_clean["name"].apply(check_for_setting)
dataframe_clean = dataframe_clean.set_index("name")

# %%
has_setting = dataframe_clean[dataframe_clean["has_setting"]]
has_setting.shape
# Out:
# (3423, 9)

# %% [markdown]
# **2669 rows in dataset respond with True for a column "has_setting"**

# %% [markdown]
# **2. Changing the datatype in column "release_date" to an int which indicates the year of releas.**

# %%
dataframe_clean["release_date"] = pd.to_datetime(dataframe_clean["release_date"], 
                                                 format="%b %d, %Y", errors="coerce").dt.year.astype("Int64")

# %% [markdown]
# **Checking if some data was lost in a process and deleting rows where it is absent.**

# %%
dataframe_clean.loc[dataframe_clean["release_date"].isna()].index
# Out:
# Index(['Steel Division 2', 'Vampire: The Masquerade® - Bloodlines™ 2',
#        'Aura Kingdom', 'League of Maidens®', 'Technobabylon',
#        'Age of Wonders Shadow Magic', 'Puzzle Agent',
#        'NECROPOLIS: BRUTAL EDITION', 'Red Stone Online',
#        'Silent Hunter 5®: Battle of the Atlantic',
#        ...
#        'Zombie Rollerz', 'Torn Asunder', 'Ruins to Rumble',
#        'Touch Type Tale - Strategic Typing', '温室之城（Glass City : The Dust）',
#        'Organism8', 'Mike goes on hike', 'Paws and Soul', 'Gamers Club',
#        'Gravia'],
#       dtype='object', name='name', length=1568)

# %%
dataframe_clean = dataframe_clean.drop(dataframe_clean.loc[dataframe_clean["release_date"].isna()].index)
dataframe_clean.loc[dataframe_clean["release_date"].isna()].index
# Out:
# Index([], dtype='object', name='name')

# %%
dataframe_clean.head()
# Out:
#                                                                      all_reviews
# name
# DOOM                           Very Positive,(42,550),- 92% of the 42,550 use...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Mixed,(836,608),- 49% of the 836,608 user revi...
# BATTLETECH                     Mostly Positive,(7,030),- 71% of the 7,030 use...
# DayZ                           Mixed,(167,115),- 61% of the 167,115 user revi...
# EVE Online                     Mostly Positive,(11,481),- 74% of the 11,481 u...
#
#                                release_date            developer
# name
# DOOM                                   2016          id Software  \
# PLAYERUNKNOWN'S BATTLEGROUNDS          2017     PUBG Corporation
# BATTLETECH                             2018  Harebrained Schemes
# DayZ                                   2018  Bohemia Interactive
# EVE Online                             2003                  CCP
#
#                                                              publisher
# name
# DOOM                             Bethesda Softworks,Bethesda Softworks  \
# PLAYERUNKNOWN'S BATTLEGROUNDS        PUBG Corporation,PUBG Corporation
# BATTLETECH                     Paradox Interactive,Paradox Interactive
# DayZ                           Bohemia Interactive,Bohemia Interactive
# EVE Online                                                     CCP,CCP
#
#                                                                     popular_tags
# name
# DOOM                           FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# BATTLETECH                     Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# DayZ                           Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# EVE Online                     Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                                                     game_details
# name
# DOOM                           Single-player,Multi-player,Co-op,Steam Achieve...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Multi-player,Online Multi-Player,Stats
# BATTLETECH                     Single-player,Multi-player,Online Multi-Player...
# DayZ                           Multi-player,Online Multi-Player,Steam Worksho...
# EVE Online                     Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                                                        languages
# name
# DOOM                           English,French,Italian,German,Spanish - Spain,...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  English,Korean,Simplified Chinese,French,Germa...
# BATTLETECH                                         English,French,German,Russian
# DayZ                           English,French,Italian,German,Spanish - Spain,...
# EVE Online                                         English,German,Russian,French
#
#                                                                            genre
# name
# DOOM                                                                      Action  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Action,Adventure,Massively Multiplayer
# BATTLETECH                                             Action,Adventure,Strategy
# DayZ                                      Action,Adventure,Massively Multiplayer
# EVE Online                     Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                has_setting
# name
# DOOM                                 False
# PLAYERUNKNOWN'S BATTLEGROUNDS        False
# BATTLETECH                           False
# DayZ                                 False
# EVE Online                           False

# %% [markdown]
# **33 rows were deleted in a process.**

# %% [markdown]
# **3. Creating the column "published_by_developer". The column will have a boolean type of data regarding the data in columns "publisher" and "developer".**

# %% [markdown]
# **removing the duplicated strings in column "publisher".**

# %%
# function spilts the string and returns unuiqe part of it
def remove_duplicates(string):
    publishers = string.split(",")
    unique_publishers = list(set(publishers))
    return ",".join(unique_publishers)

# %%
dataframe_clean["publisher"] = dataframe_clean["publisher"].apply(remove_duplicates)

# %%
dataframe_clean.head()
# Out:
#                                                                      all_reviews
# name
# DOOM                           Very Positive,(42,550),- 92% of the 42,550 use...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Mixed,(836,608),- 49% of the 836,608 user revi...
# BATTLETECH                     Mostly Positive,(7,030),- 71% of the 7,030 use...
# DayZ                           Mixed,(167,115),- 61% of the 167,115 user revi...
# EVE Online                     Mostly Positive,(11,481),- 74% of the 11,481 u...
#
#                                release_date            developer
# name
# DOOM                                   2016          id Software  \
# PLAYERUNKNOWN'S BATTLEGROUNDS          2017     PUBG Corporation
# BATTLETECH                             2018  Harebrained Schemes
# DayZ                                   2018  Bohemia Interactive
# EVE Online                             2003                  CCP
#
#                                          publisher
# name
# DOOM                            Bethesda Softworks  \
# PLAYERUNKNOWN'S BATTLEGROUNDS     PUBG Corporation
# BATTLETECH                     Paradox Interactive
# DayZ                           Bohemia Interactive
# EVE Online                                     CCP
#
#                                                                     popular_tags
# name
# DOOM                           FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# BATTLETECH                     Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# DayZ                           Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# EVE Online                     Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                                                     game_details
# name
# DOOM                           Single-player,Multi-player,Co-op,Steam Achieve...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Multi-player,Online Multi-Player,Stats
# BATTLETECH                     Single-player,Multi-player,Online Multi-Player...
# DayZ                           Multi-player,Online Multi-Player,Steam Worksho...
# EVE Online                     Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                                                        languages
# name
# DOOM                           English,French,Italian,German,Spanish - Spain,...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  English,Korean,Simplified Chinese,French,Germa...
# BATTLETECH                                         English,French,German,Russian
# DayZ                           English,French,Italian,German,Spanish - Spain,...
# EVE Online                                         English,German,Russian,French
#
#                                                                            genre
# name
# DOOM                                                                      Action  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Action,Adventure,Massively Multiplayer
# BATTLETECH                                             Action,Adventure,Strategy
# DayZ                                      Action,Adventure,Massively Multiplayer
# EVE Online                     Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                has_setting
# name
# DOOM                                 False
# PLAYERUNKNOWN'S BATTLEGROUNDS        False
# BATTLETECH                           False
# DayZ                                 False
# EVE Online                           False

# %% [markdown]
# **Creating the column "published_by_developer" and deliting columns "developer" and "publisher".**

# %%
dataframe_clean["published_by_developer"] = dataframe_clean["developer"] == dataframe_clean["publisher"]

# %%
published_by_developer = dataframe_clean[dataframe_clean["published_by_developer"]]
dataframe_clean = dataframe_clean.drop(["developer", "publisher"], axis=1)
dataframe_clean.head()
# Out:
#                                                                      all_reviews
# name
# DOOM                           Very Positive,(42,550),- 92% of the 42,550 use...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Mixed,(836,608),- 49% of the 836,608 user revi...
# BATTLETECH                     Mostly Positive,(7,030),- 71% of the 7,030 use...
# DayZ                           Mixed,(167,115),- 61% of the 167,115 user revi...
# EVE Online                     Mostly Positive,(11,481),- 74% of the 11,481 u...
#
#                                release_date
# name
# DOOM                                   2016  \
# PLAYERUNKNOWN'S BATTLEGROUNDS          2017
# BATTLETECH                             2018
# DayZ                                   2018
# EVE Online                             2003
#
#                                                                     popular_tags
# name
# DOOM                           FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# BATTLETECH                     Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# DayZ                           Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# EVE Online                     Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                                                     game_details
# name
# DOOM                           Single-player,Multi-player,Co-op,Steam Achieve...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Multi-player,Online Multi-Player,Stats
# BATTLETECH                     Single-player,Multi-player,Online Multi-Player...
# DayZ                           Multi-player,Online Multi-Player,Steam Worksho...
# EVE Online                     Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                                                        languages
# name
# DOOM                           English,French,Italian,German,Spanish - Spain,...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  English,Korean,Simplified Chinese,French,Germa...
# BATTLETECH                                         English,French,German,Russian
# DayZ                           English,French,Italian,German,Spanish - Spain,...
# EVE Online                                         English,German,Russian,French
#
#                                                                            genre
# name
# DOOM                                                                      Action  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Action,Adventure,Massively Multiplayer
# BATTLETECH                                             Action,Adventure,Strategy
# DayZ                                      Action,Adventure,Massively Multiplayer
# EVE Online                     Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                has_setting  published_by_developer
# name
# DOOM                                 False                   False
# PLAYERUNKNOWN'S BATTLEGROUNDS        False                    True
# BATTLETECH                           False                   False
# DayZ                                 False                    True
# EVE Online                           False                    True

# %% [markdown]
# **4. Creating the column "multiple_languages". The column will have a boolean type of data regarding the data in column "languages". Drop the cloumn "languages" after data extraction.**

# %%
dataframe_clean["multiple_languages"] = dataframe_clean["languages"].str.split(",").apply(lambda x: len(x) > 1)
dataframe_clean = dataframe_clean.drop(["languages"], axis=1)
dataframe_clean.head()
# Out:
#                                                                      all_reviews
# name
# DOOM                           Very Positive,(42,550),- 92% of the 42,550 use...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Mixed,(836,608),- 49% of the 836,608 user revi...
# BATTLETECH                     Mostly Positive,(7,030),- 71% of the 7,030 use...
# DayZ                           Mixed,(167,115),- 61% of the 167,115 user revi...
# EVE Online                     Mostly Positive,(11,481),- 74% of the 11,481 u...
#
#                                release_date
# name
# DOOM                                   2016  \
# PLAYERUNKNOWN'S BATTLEGROUNDS          2017
# BATTLETECH                             2018
# DayZ                                   2018
# EVE Online                             2003
#
#                                                                     popular_tags
# name
# DOOM                           FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# BATTLETECH                     Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# DayZ                           Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# EVE Online                     Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                                                     game_details
# name
# DOOM                           Single-player,Multi-player,Co-op,Steam Achieve...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Multi-player,Online Multi-Player,Stats
# BATTLETECH                     Single-player,Multi-player,Online Multi-Player...
# DayZ                           Multi-player,Online Multi-Player,Steam Worksho...
# EVE Online                     Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                                                            genre
# name
# DOOM                                                                      Action  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Action,Adventure,Massively Multiplayer
# BATTLETECH                                             Action,Adventure,Strategy
# DayZ                                      Action,Adventure,Massively Multiplayer
# EVE Online                     Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                has_setting  published_by_developer
# name
# DOOM                                 False                   False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS        False                    True
# BATTLETECH                           False                   False
# DayZ                                 False                    True
# EVE Online                           False                    True
#
#                                multiple_languages
# name
# DOOM                                         True
# PLAYERUNKNOWN'S BATTLEGROUNDS                True
# BATTLETECH                                   True
# DayZ                                         True
# EVE Online                                   True

# %%
multiple_languages = dataframe_clean[dataframe_clean["multiple_languages"]]
multiple_languages.shape
# Out:
# (16071, 8)

# %% [markdown]
# **13610 rows respond with True for column "multiple_languages".**

# %% [markdown]
# **5. Creating multiple columns regarding unique tags, details and genres. They will store boolean data type regarding the string they were extracted from.**

# %% [markdown]
# **Listing and counting the tags from column "popular_tags".**

# %%
all_tags = ",".join(dataframe_clean["popular_tags"])
tag_list = all_tags.split(',')
tag_counts = Counter(tag_list)
most_popular_tags = tag_counts.most_common()
print("Most popular tags:")
for tag, count in most_popular_tags:
    if count > 300:
        print(f"{tag}: {count}")
# Out:
# Most popular tags:
# Indie: 19636
# Action: 13745
# Adventure: 11320
# Casual: 10797
# Simulation: 7147
# Strategy: 6707
# Singleplayer: 6208
# Early Access: 5553
# RPG: 5524
# Great Soundtrack: 2921
# 2D: 2835
# Multiplayer: 2809
# Atmospheric: 2805
# Puzzle: 2731
# Free to Play: 2285
# VR: 2227
# Violent: 1949
# Story Rich: 1926
# Difficult: 1924
# Horror: 1732
# Anime: 1712
# Gore: 1637
# Pixel Graphics: 1607
# Sports: 1580
# Funny: 1576
# Platformer: 1575
# Shooter: 1556
# Sci-fi: 1493
# Female Protagonist: 1485
# Open World: 1484
# First-Person: 1481
# Fantasy: 1469
# Co-op: 1450
# Retro: 1372
# Arcade: 1284
# Racing: 1281
# Nudity: 1256
# FPS: 1238
# Family Friendly: 1164
# Survival: 1149
# Massively Multiplayer: 1075
# Visual Novel: 1065
# Comedy: 1040
# Sexual Content: 1037
# Sandbox: 1029
# Cute: 986
# Classic: 985
# Point & Click: 952
# Exploration: 882
# Turn-Based: 881
# Masterpiece: 878
# Replay Value: 830
# Space: 803
# Relaxing: 799
# Psychological Horror: 757
# Third Person: 750
# Local Multiplayer: 658
# Colorful: 653
# Fast-Paced: 634
# Tactical: 624
# Mystery: 623
# RPGMaker: 619
# Controller: 605
# Physics: 604
# Zombies: 601
# Rogue-like: 593
# Local Co-Op: 586
# Shoot 'Em Up: 570
# Management: 560
# Side Scroller: 559
# Hidden Object: 558
# Short: 555
# Building: 542
# Dark: 536
# Turn-Based Strategy: 535
# Online Co-Op: 533
# Design & Illustration: 527
# Memes: 526
# RTS: 486
# Survival Horror: 484
# Realistic: 477
# Historical: 464
# Puzzle-Platformer: 460
# War: 433
# Top-Down: 431
# Choices Matter: 421
# Action RPG: 413
# Minimalist: 407
# Bullet Hell: 404
# Web Publishing: 395
# Music: 394
# Crafting: 392
# Rogue-lite: 388
# JRPG: 382
# Tower Defense: 377
# Hack and Slash: 375
# Stealth: 373
# Competitive: 342
# Mature: 341
# Walking Simulator: 337
# Fighting: 334
# Dungeon Crawler: 331
# Education: 331
# 4 Player Local: 329
# PvP: 324
# Procedural Generation: 319
# Card Game: 318
# Isometric: 317
# Turn-Based Combat: 315
# Post-apocalyptic: 306
# Action-Adventure: 302
# Moddable: 301

# %% [markdown]
# **Creating new columns according to uniqe tags. The count to create a new column will require more then 1300 entries for a tag.**

# %%
the_most_popular_tags = [(tag, count) for tag, count in tag_counts.items() if count > 300]
for tag, count in the_most_popular_tags:
    dataframe_clean[tag] = dataframe_clean["popular_tags"].apply(lambda x: tag in x)

# %%
dataframe_clean.head()
# Out:
#                                                                      all_reviews
# name
# DOOM                           Very Positive,(42,550),- 92% of the 42,550 use...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Mixed,(836,608),- 49% of the 836,608 user revi...
# BATTLETECH                     Mostly Positive,(7,030),- 71% of the 7,030 use...
# DayZ                           Mixed,(167,115),- 61% of the 167,115 user revi...
# EVE Online                     Mostly Positive,(11,481),- 74% of the 11,481 u...
#
#                                release_date
# name
# DOOM                                   2016  \
# PLAYERUNKNOWN'S BATTLEGROUNDS          2017
# BATTLETECH                             2018
# DayZ                                   2018
# EVE Online                             2003
#
#                                                                     popular_tags
# name
# DOOM                           FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# BATTLETECH                     Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# DayZ                           Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# EVE Online                     Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                                                     game_details
# name
# DOOM                           Single-player,Multi-player,Co-op,Steam Achieve...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Multi-player,Online Multi-Player,Stats
# BATTLETECH                     Single-player,Multi-player,Online Multi-Player...
# DayZ                           Multi-player,Online Multi-Player,Steam Worksho...
# EVE Online                     Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                                                            genre
# name
# DOOM                                                                      Action  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Action,Adventure,Massively Multiplayer
# BATTLETECH                                             Action,Adventure,Strategy
# DayZ                                      Action,Adventure,Massively Multiplayer
# EVE Online                     Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                has_setting  published_by_developer
# name
# DOOM                                 False                   False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS        False                    True
# BATTLETECH                           False                   False
# DayZ                                 False                    True
# EVE Online                           False                    True
#
#                                multiple_languages    FPS   Gore  ...
# name                                                             ...
# DOOM                                         True   True   True  ...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                True   True  False  ...
# BATTLETECH                                   True  False  False  ...
# DayZ                                         True   True  False  ...
# EVE Online                                   True  False  False  ...
#
#                                Replay Value  Education  Design & Illustration
# name
# DOOM                                  False      False                  False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS         False      False                  False
# BATTLETECH                            False      False                  False
# DayZ                                  False      False                  False
# EVE Online                            False      False                  False
#
#                                Procedural Generation  Music  Shoot 'Em Up
# name
# DOOM                                           False  False         False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                  False  False         False
# BATTLETECH                                     False  False         False
# DayZ                                           False  False         False
# EVE Online                                     False  False         False
#
#                                RPGMaker  Web Publishing  Hidden Object
# name
# DOOM                              False           False          False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS     False           False          False
# BATTLETECH                        False           False          False
# DayZ                              False           False          False
# EVE Online                        False           False          False
#
#                                Minimalist
# name
# DOOM                                False
# PLAYERUNKNOWN'S BATTLEGROUNDS       False
# BATTLETECH                          False
# DayZ                                False
# EVE Online                          False
#
# [5 rows x 120 columns]

# %% [markdown]
# **Listing and counting the tags from column "game_details".**

# %%
all_details = ",".join(dataframe_clean["game_details"])
details_list = all_details.split(',')
details_counts = Counter(details_list)
most_popular_details = details_counts.most_common()
print("Most popular details:")
for detail, count in most_popular_details:
    if count > 300:
        print(f"{detail}: {count}")
# Out:
# Most popular details:
# Single-player: 28370
# Steam Achievements: 16424
# Steam Cloud: 9443
# Steam Trading Cards: 9389
# Downloadable Content: 8346
# Full controller support: 7345
# Profile Features Limited
# 									: 6602
# Multi-player: 6243
# Partial Controller Support: 5223
# Steam Leaderboards: 4454
# Online Multi-Player: 3426
# Co-op: 2874
# Shared/Split Screen: 2608
# Stats: 2211
# Local Multi-Player: 1788
# Steam Workshop: 1692
# Online Co-op: 1565
# Cross-Platform Multiplayer: 1420
# Includes level editor: 1244
# Steam is learning about this game
# 									: 1225
# Local Co-op: 1109
# In-App Purchases: 1036
# Captions available: 868
# MMO: 632

# %%
the_most_popular_details = [(detail, count) for detail, count in details_counts.items() if count > 500]
for detail, count in the_most_popular_details:
    new_column_name = f"detail_{detail}"
    dataframe_clean[new_column_name] = dataframe_clean["game_details"].apply(lambda x: detail in x)

# %%
dataframe_clean.head()
# Out:
#                                                                      all_reviews
# name
# DOOM                           Very Positive,(42,550),- 92% of the 42,550 use...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Mixed,(836,608),- 49% of the 836,608 user revi...
# BATTLETECH                     Mostly Positive,(7,030),- 71% of the 7,030 use...
# DayZ                           Mixed,(167,115),- 61% of the 167,115 user revi...
# EVE Online                     Mostly Positive,(11,481),- 74% of the 11,481 u...
#
#                                release_date
# name
# DOOM                                   2016  \
# PLAYERUNKNOWN'S BATTLEGROUNDS          2017
# BATTLETECH                             2018
# DayZ                                   2018
# EVE Online                             2003
#
#                                                                     popular_tags
# name
# DOOM                           FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# BATTLETECH                     Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# DayZ                           Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# EVE Online                     Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                                                     game_details
# name
# DOOM                           Single-player,Multi-player,Co-op,Steam Achieve...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Multi-player,Online Multi-Player,Stats
# BATTLETECH                     Single-player,Multi-player,Online Multi-Player...
# DayZ                           Multi-player,Online Multi-Player,Steam Worksho...
# EVE Online                     Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                                                            genre
# name
# DOOM                                                                      Action  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Action,Adventure,Massively Multiplayer
# BATTLETECH                                             Action,Adventure,Strategy
# DayZ                                      Action,Adventure,Massively Multiplayer
# EVE Online                     Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                has_setting  published_by_developer
# name
# DOOM                                 False                   False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS        False                    True
# BATTLETECH                           False                   False
# DayZ                                 False                    True
# EVE Online                           False                    True
#
#                                multiple_languages    FPS   Gore  ...
# name                                                             ...
# DOOM                                         True   True   True  ...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                True   True  False  ...
# BATTLETECH                                   True  False  False  ...
# DayZ                                         True   True  False  ...
# EVE Online                                   True  False  False  ...
#
#                                detail_Local Co-op  detail_Shared/Split Screen
# name
# DOOM                                        False                       False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS               False                       False
# BATTLETECH                                  False                       False
# DayZ                                        False                       False
# EVE Online                                  False                       False
#
#                                detail_Steam Leaderboards
# name
# DOOM                                               False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                      False
# BATTLETECH                                         False
# DayZ                                               False
# EVE Online                                         False
#
#                                detail_Local Multi-Player
# name
# DOOM                                               False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                      False
# BATTLETECH                                         False
# DayZ                                               False
# EVE Online                                         False
#
#                                detail_Captions available
# name
# DOOM                                               False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                      False
# BATTLETECH                                         False
# DayZ                                               False
# EVE Online                                         False
#
#                                detail_Includes level editor
# name
# DOOM                                                  False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                         False
# BATTLETECH                                            False
# DayZ                                                  False
# EVE Online                                            False
#
#                                detail_In-App Purchases
# name
# DOOM                                             False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                    False
# BATTLETECH                                       False
# DayZ                                             False
# EVE Online                                       False
#
#                                detail_Profile Features Limited \r\n\t\t\t\t\t\t\t\t\t
# name
# DOOM                                                                       False       \
# PLAYERUNKNOWN'S BATTLEGROUNDS                                              False
# BATTLETECH                                                                 False
# DayZ                                                                       False
# EVE Online                                                                 False
#
#                                detail_Steam is learning about this game \r\n\t\t\t\t\t\t\t\t\t
# name
# DOOM                                                                       False                \
# PLAYERUNKNOWN'S BATTLEGROUNDS                                              False
# BATTLETECH                                                                 False
# DayZ                                                                       False
# EVE Online                                                                 False
#
#                                detail_Downloadable Content
# name
# DOOM                                                 False
# PLAYERUNKNOWN'S BATTLEGROUNDS                        False
# BATTLETECH                                           False
# DayZ                                                 False
# EVE Online                                           False
#
# [5 rows x 144 columns]

# %% [markdown]
# **Listing and counting the tags from column "genre".**

# %%
all_genres = ",".join(dataframe_clean["genre"])
genre_list = all_genres.split(",")
genre_counts = Counter(genre_list)
most_popular_genres = [(genre, count) for genre, count in genre_counts.items() if count > 300]
print("Most popular genres:")
for genre, count in most_popular_genres:
    print(f"{genre}: {count}")
# Out:
# Most popular genres:
# Action: 12996
# Adventure: 10173
# Massively Multiplayer: 947
# Strategy: 6158
# Free to Play: 2079
# RPG: 5161
# Indie: 18864
# Early Access: 2485
# Simulation: 6627
# Racing: 1212
# Casual: 9921
# Sports: 1499
# Design & Illustration: 486
# Web Publishing: 391

# %%
the_most_popular_genres = [(genre, count) for genre, count in genre_counts.items() if count > 500]
for genre, count in the_most_popular_genres:
    new_column_name = f"genre_{genre}"
    dataframe_clean[new_column_name] = dataframe_clean["genre"].apply(lambda x: genre in x)

# %%
dataframe_clean.head()
# Out:
#                                                                      all_reviews
# name
# DOOM                           Very Positive,(42,550),- 92% of the 42,550 use...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Mixed,(836,608),- 49% of the 836,608 user revi...
# BATTLETECH                     Mostly Positive,(7,030),- 71% of the 7,030 use...
# DayZ                           Mixed,(167,115),- 61% of the 167,115 user revi...
# EVE Online                     Mostly Positive,(11,481),- 74% of the 11,481 u...
#
#                                release_date
# name
# DOOM                                   2016  \
# PLAYERUNKNOWN'S BATTLEGROUNDS          2017
# BATTLETECH                             2018
# DayZ                                   2018
# EVE Online                             2003
#
#                                                                     popular_tags
# name
# DOOM                           FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# BATTLETECH                     Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# DayZ                           Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# EVE Online                     Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                                                     game_details
# name
# DOOM                           Single-player,Multi-player,Co-op,Steam Achieve...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Multi-player,Online Multi-Player,Stats
# BATTLETECH                     Single-player,Multi-player,Online Multi-Player...
# DayZ                           Multi-player,Online Multi-Player,Steam Worksho...
# EVE Online                     Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                                                            genre
# name
# DOOM                                                                      Action  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             Action,Adventure,Massively Multiplayer
# BATTLETECH                                             Action,Adventure,Strategy
# DayZ                                      Action,Adventure,Massively Multiplayer
# EVE Online                     Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                has_setting  published_by_developer
# name
# DOOM                                 False                   False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS        False                    True
# BATTLETECH                           False                   False
# DayZ                                 False                    True
# EVE Online                           False                    True
#
#                                multiple_languages    FPS   Gore  ...
# name                                                             ...
# DOOM                                         True   True   True  ...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                True   True  False  ...
# BATTLETECH                                   True  False  False  ...
# DayZ                                         True   True  False  ...
# EVE Online                                   True  False  False  ...
#
#                                genre_Massively Multiplayer  genre_Strategy
# name
# DOOM                                                 False           False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                         True           False
# BATTLETECH                                           False            True
# DayZ                                                  True           False
# EVE Online                                            True            True
#
#                                genre_Free to Play  genre_RPG  genre_Indie
# name
# DOOM                                        False      False        False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS               False      False        False
# BATTLETECH                                  False      False        False
# DayZ                                        False      False        False
# EVE Online                                   True       True        False
#
#                                genre_Early Access  genre_Simulation
# name
# DOOM                                        False             False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS               False             False
# BATTLETECH                                  False             False
# DayZ                                        False             False
# EVE Online                                  False             False
#
#                                genre_Racing  genre_Casual  genre_Sports
# name
# DOOM                                  False         False         False
# PLAYERUNKNOWN'S BATTLEGROUNDS         False         False         False
# BATTLETECH                            False         False         False
# DayZ                                  False         False         False
# EVE Online                            False         False         False
#
# [5 rows x 156 columns]

# %% [markdown]
# **Deleting the columns "genre", "popular_tags" and "game_details" as I no longer need them.**

# %%
dataframe_clean = dataframe_clean.drop(["genre", "popular_tags", "game_details"], axis=1)
dataframe_clean.head()
# Out:
#                                                                      all_reviews
# name
# DOOM                           Very Positive,(42,550),- 92% of the 42,550 use...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  Mixed,(836,608),- 49% of the 836,608 user revi...
# BATTLETECH                     Mostly Positive,(7,030),- 71% of the 7,030 use...
# DayZ                           Mixed,(167,115),- 61% of the 167,115 user revi...
# EVE Online                     Mostly Positive,(11,481),- 74% of the 11,481 u...
#
#                                release_date  has_setting
# name
# DOOM                                   2016        False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS          2017        False
# BATTLETECH                             2018        False
# DayZ                                   2018        False
# EVE Online                             2003        False
#
#                                published_by_developer  multiple_languages
# name
# DOOM                                            False                True  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                    True                True
# BATTLETECH                                      False                True
# DayZ                                             True                True
# EVE Online                                       True                True
#
#                                  FPS   Gore  Action  Shooter  First-Person
# name
# DOOM                            True   True    True     True          True  \
# PLAYERUNKNOWN'S BATTLEGROUNDS   True  False    True     True          True
# BATTLETECH                     False  False    True    False         False
# DayZ                            True  False    True     True         False
# EVE Online                     False  False    True    False         False
#
#                                ...  genre_Massively Multiplayer
# name                           ...
# DOOM                           ...                        False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS  ...                         True
# BATTLETECH                     ...                        False
# DayZ                           ...                         True
# EVE Online                     ...                         True
#
#                                genre_Strategy  genre_Free to Play  genre_RPG
# name
# DOOM                                    False               False      False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS           False               False      False
# BATTLETECH                               True               False      False
# DayZ                                    False               False      False
# EVE Online                               True                True       True
#
#                                genre_Indie  genre_Early Access
# name
# DOOM                                 False               False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS        False               False
# BATTLETECH                           False               False
# DayZ                                 False               False
# EVE Online                           False               False
#
#                                genre_Simulation  genre_Racing  genre_Casual
# name
# DOOM                                      False         False         False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS             False         False         False
# BATTLETECH                                False         False         False
# DayZ                                      False         False         False
# EVE Online                                False         False         False
#
#                                genre_Sports
# name
# DOOM                                  False
# PLAYERUNKNOWN'S BATTLEGROUNDS         False
# BATTLETECH                            False
# DayZ                                  False
# EVE Online                            False
#
# [5 rows x 153 columns]

# %%
dataframe_clean.shape
# Out:
# (30675, 153)

# %% [markdown]
# **6. Creating columns "total_reviews" and "positive_reviews_share" regarding the column "all_reviews". They will contain int and float data type accordingly.**

# %% [markdown]
# **Checking if all rows have a sufficient string to extract data. Deleting those which do not have.**

# %%
# function extracts first and second number from a string and returns them as int and float data type accordingly
def extract_numbers(string):
    total_reviews = None
    positive_reviews_share = None
    match_total = re.search(r"\(([\d,]+)\)", string)
    match_positive = re.search(r"(\d+)%", string)
    if match_total:
        total_reviews = int(match_total.group(1).replace(",", ""))
    if match_positive:
        positive_reviews_share = float(match_positive.group(1)) / 100
    return total_reviews, positive_reviews_share

# %%
def replace_string_or_fill_na(text):
    if text is None or "Need more" in str(text):
        random_number = random.randint(10, 1000)
        random_float = round(random.uniform(0.01, 1.00), 2)
        return f"{random_number} user reviews, {random_float}"
    return text

# %%
dataframe_clean["all_reviews"] = dataframe_clean["all_reviews"].astype(str).apply(replace_string_or_fill_na)

# %%
dataframe_clean[["total_reviews", 
                 "positive_reviews_share"]] = dataframe_clean["all_reviews"].apply(lambda x: pd.Series(extract_numbers(x)))

# %%
min_value = 10
max_value = 1000

dataframe_clean["total_reviews"] = dataframe_clean["total_reviews"].apply(lambda x: random.randint(
    min_value, max_value) if pd.isnull(x) else x)

# %%
min_value = 0.01
max_value = 1.00

dataframe_clean["positive_reviews_share"] = dataframe_clean["positive_reviews_share"].apply(lambda x: round(random.uniform(
    min_value, max_value), 2) if pd.isnull(x) else x)

# %% [markdown]
# **Deleting the column "all_reviews" as data was exctracted already.**

# %%
dataframe_clean = dataframe_clean.drop(["all_reviews"], axis=1)

# %% [markdown]
# **Checking on how dataset looks like now.**

# %%
dataframe_clean
# Out:
#                                              release_date  has_setting
# name
# DOOM                                                 2016        False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                        2017        False
# BATTLETECH                                           2018        False
# DayZ                                                 2018        False
# EVE Online                                           2003        False
# ...                                                   ...          ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)          2019        False
# Galactis                                             2018        False
# Alive                                                2019        False
# Mega Man X5 Sound Collection                         2018         True
# Stories In Stone                                     2018        False
#
#                                              published_by_developer
# name
# DOOM                                                          False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                                  True
# BATTLETECH                                                    False
# DayZ                                                           True
# EVE Online                                                     True
# ...                                                             ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)                    True
# Galactis                                                       True
# Alive                                                          True
# Mega Man X5 Sound Collection                                   True
# Stories In Stone                                              False
#
#                                              multiple_languages    FPS   Gore
# name
# DOOM                                                       True   True   True  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                              True   True  False
# BATTLETECH                                                 True  False  False
# DayZ                                                       True   True  False
# EVE Online                                                 True  False  False
# ...                                                         ...    ...    ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)               False  False  False
# Galactis                                                  False  False  False
# Alive                                                     False   True  False
# Mega Man X5 Sound Collection                               True  False  False
# Stories In Stone                                          False  False  False
#
#                                              Action  Shooter  First-Person
# name
# DOOM                                           True     True          True  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                  True     True          True
# BATTLETECH                                     True    False         False
# DayZ                                           True     True         False
# EVE Online                                     True    False         False
# ...                                             ...      ...           ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)   False    False         False
# Galactis                                       True    False         False
# Alive                                          True    False         False
# Mega Man X5 Sound Collection                   True    False         False
# Stories In Stone                              False    False         False
#
#                                              Great Soundtrack  ...
# name                                                           ...
# DOOM                                                     True  ...  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                           False  ...
# BATTLETECH                                               True  ...
# DayZ                                                    False  ...
# EVE Online                                              False  ...
# ...                                                       ...  ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)             False  ...
# Galactis                                                False  ...
# Alive                                                   False  ...
# Mega Man X5 Sound Collection                            False  ...
# Stories In Stone                                        False  ...
#
#                                              genre_Free to Play  genre_RPG
# name
# DOOM                                                      False      False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                             False      False
# BATTLETECH                                                False      False
# DayZ                                                      False      False
# EVE Online                                                 True       True
# ...                                                         ...        ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)               False      False
# Galactis                                                  False      False
# Alive                                                      True       True
# Mega Man X5 Sound Collection                              False      False
# Stories In Stone                                          False       True
#
#                                              genre_Indie  genre_Early Access
# name
# DOOM                                               False               False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                      False               False
# BATTLETECH                                         False               False
# DayZ                                               False               False
# EVE Online                                         False               False
# ...                                                  ...                 ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)         True               False
# Galactis                                            True               False
# Alive                                              False               False
# Mega Man X5 Sound Collection                       False               False
# Stories In Stone                                   False               False
#
#                                              genre_Simulation  genre_Racing
# name
# DOOM                                                    False         False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                           False         False
# BATTLETECH                                              False         False
# DayZ                                                    False         False
# EVE Online                                              False         False
# ...                                                       ...           ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)             False         False
# Galactis                                                False         False
# Alive                                                   False         False
# Mega Man X5 Sound Collection                            False         False
# Stories In Stone                                        False         False
#
#                                              genre_Casual  genre_Sports
# name
# DOOM                                                False         False  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                       False         False
# BATTLETECH                                          False         False
# DayZ                                                False         False
# EVE Online                                          False         False
# ...                                                   ...           ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)          True         False
# Galactis                                            False         False
# Alive                                               False         False
# Mega Man X5 Sound Collection                        False         False
# Stories In Stone                                    False         False
#
#                                              total_reviews
# name
# DOOM                                               42550.0  \
# PLAYERUNKNOWN'S BATTLEGROUNDS                     836608.0
# BATTLETECH                                          7030.0
# DayZ                                              167115.0
# EVE Online                                         11481.0
# ...                                                    ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)          695.0
# Galactis                                             426.0
# Alive                                                206.0
# Mega Man X5 Sound Collection                         640.0
# Stories In Stone                                     823.0
#
#                                              positive_reviews_share
# name
# DOOM                                                           0.92
# PLAYERUNKNOWN'S BATTLEGROUNDS                                  0.49
# BATTLETECH                                                     0.71
# DayZ                                                           0.61
# EVE Online                                                     0.74
# ...                                                             ...
# Bare Boob Brawlerz: Novel 01 (Visual Novel)                    0.99
# Galactis                                                       0.98
# Alive                                                          0.23
# Mega Man X5 Sound Collection                                   0.33
# Stories In Stone                                               0.75
#
# [30675 rows x 154 columns]

# %% [markdown]
# # 3 Saving the reshaped dataset

# %%
dataframe_clean.to_csv("Datasets/steam_games_test_03.csv", index=False)
